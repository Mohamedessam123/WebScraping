# %%
import requests
from bs4 import BeautifulSoup

Date = input('Please enter the date in the following format MM/DD/YY: ')



url = f'https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={Date}#'
response = requests.get(url)
content = response.content
# Out:
# Please enter the date in the following format MM/DD/YY: 6/8/2024

# %%
soup = BeautifulSoup(content,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ar">
# <head>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/ykicons.woff2?ver=1" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/droidkufi-regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/droidkufi-bold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/Stories/swiper-icons.woff2" rel="preload" type="font/woff2"/>
# <!-- Preloading -->
# <link as="style" crossorigin="" href="/Content/StyleOnLoad.css?ver=0.1" rel="preload"/>
# <!-- strat: Chartbeat-->
# <script type="text/javascript">
#         var _sf_startpt = (new Date()).getTime()
#     </script>
# <!-- end: chartbeat-->
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# ...

# %%
champions = soup.find_all('div',{'class':'matchCard'})
champions
# Out:
# [<div class="2834 matchCard matchesList">
#  <div class="title">
#  <a class="tourTitle" href="/world-cup-african-qualifiers-/2834/tour-hp/%d8%aa%d8%b5%d9%81%d9%8a%d8%a7%d8%aa-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d8%a5%d9%81%d8%b1%d9%8a%d9%82%d9%8a%d8%a7#MC_MatcheDetails">
#  <div class="imgCntnr">
#  <img alt="لوجو" data-src="https://www.yallakora.com/pictures/Tourlogo/caf119-12-2019-17-31-32.png" enname="World Cup African Qualifiers " height="26" loading="lazy" src="https://www.yallakora.com/pictures/Tourlogo/caf119-12-2019-17-31-32.png" width="26"/>
#  </div>
#  <h2>
#                                          تصفيات كأس العالم-إفريقيا
#                                      </h2>
#  </a>
#  <div class="links">
#  <a class="more" href="/world-cup-african-qualifiers-/2834/tour-news/%d8%aa%d8%b5%d9%81%d9%8a%d8%a7%d8%aa-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d8%a5%d9%81%d8%b1%d9%8a%d9%82%d9%8a%d8%a7#Matches-newslisting" title="أخبار">أخبار</a>
# ...

# %%
def get_channel(champions):
    for i in range(len(champions)):
        Channel = champions[i].contents[3].find('div',{'class':'channel icon-channel'}).text.strip()
        if Channel :
            return Channel
        else:
            return('Empty')

# %%
get_channel(champions)
# Out:
# 'SSc SPORT'

# %%
all_matches=[]

# %%
for i in range(len(champions)):
    matches = champions[i].find_all('div',{'class':'item finish liItem'})
    all_matches.append(matches)
    
    print(len(matches))
# Out:
# 2
# 4
# 1

# %%
for i in range(len(champions)):
    matches = champions[i].find_all('div',{'class':'item finish liItem'})
    print(matches)
# Out:
# [<div class="item finish liItem" livescorematchid="96306">
# <a href="/world-cup-african-qualifiers-/2834/match/96306/-%d8%a7%d9%84%d9%83%d8%a7%d9%85%d9%8a%d8%b1%d9%88%d9%86-%d9%83%d8%a7%d8%a8-%d9%81%d9%8a%d8%b1%d8%af%d9%8a-%d8%aa%d8%b5%d9%81%d9%8a%d8%a7%d8%aa-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d8%a5%d9%81%d8%b1%d9%8a%d9%82%d9%8a%d8%a7#MC_MatcheDetails" title="تفاصيل المباراة">
# <div class="allData">
# <!-- Match Top Data -->
# <div class="channel icon-channel">SSc SPORT</div>
# <!--Time & Status-->
# <div class="topData">
# <div class="date">الجولة الثالثة</div>
# <div class="matchStatus">
# <span>انتهت</span>
# </div>
# </div>
# <!--Teams-->
# <div class="teamCntnr">
# <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# ...

# %%
all_matches[0]
# Out:
# [<div class="item finish liItem" livescorematchid="96306">
#  <a href="/world-cup-african-qualifiers-/2834/match/96306/-%d8%a7%d9%84%d9%83%d8%a7%d9%85%d9%8a%d8%b1%d9%88%d9%86-%d9%83%d8%a7%d8%a8-%d9%81%d9%8a%d8%b1%d8%af%d9%8a-%d8%aa%d8%b5%d9%81%d9%8a%d8%a7%d8%aa-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d8%a5%d9%81%d8%b1%d9%8a%d9%82%d9%8a%d8%a7#MC_MatcheDetails" title="تفاصيل المباراة">
#  <div class="allData">
#  <!-- Match Top Data -->
#  <div class="channel icon-channel">SSc SPORT</div>
#  <!--Time & Status-->
#  <div class="topData">
#  <div class="date">الجولة الثالثة</div>
#  <div class="matchStatus">
#  <span>انتهت</span>
#  </div>
#  </div>
#  <!--Teams-->
#  <div class="teamCntnr">
#  <div class="teamsData">
#  <!-- Team A -->
#  <div class="teams teamA">
# ...

# %%
Channel = champions[1].contents[3].find('div',{'class':'channel icon-channel'}).text.strip()
Channel
# Out:
# 'بى ان سبورت 1HD'

# %%
match_type = champions[1].contents[3].find('div',{'class':'date'}).text.strip()
match_type
# Out:
# 'مباراة ودية'

# %%
teamA = champions[1].contents[3].find('div', {'class':'teamA'}).text.strip()
teamA
# Out:
# 'البرتغال'

# %%
teamB = champions[1].contents[3].find('div', {'class':'teamB'}).text.strip()
teamB
# Out:
# 'كرواتيا'

# %%
teamA=teamsData[0].find('div',{'class':'teamsData'}).find('div',{'class':'teamA'}).text.strip()
teamA
# Out:
# 'الأهلي'

# %%
teamB=teamsData[0].find('div',{'class':'teamsData'}).find('div',{'class':'teamB'}).text.strip()
teamB
# Out:
# 'النجوم'

# %%
scores = champions[1].contents[3].find('div',{'class':'MResult'}).find_all('span',{'class':'score'})
score1=scores[0].text.strip()
score1
# Out:
# '1'

# %%
score2=scores[1].text.strip()
score2
# Out:
# '2'

# %%
score = f"{score1}-{score2}"
score
# Out:
# '1-2'

# %%
time = champions[1].contents[3].find('div',{'class':'MResult'}).find('span',{'class':'time'}).text.strip()
time
# Out:
# '19:45'

# %%
champions[2].contents[3]
# Out:
# <div class="ul">
# <!-- Match 1 -->
# <div class="item finish liItem" livescorematchid="96603">
# <a href="/friendly-matches-club/2541/match/96603/%d8%a7%d9%84%d8%a3%d9%87%d9%84%d9%8a-%d8%a7%d9%84%d9%86%d8%ac%d9%88%d9%85-%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa-%d9%88%d8%af%d9%8a%d8%a9-%d8%a3%d9%86%d8%af%d9%8a%d8%a9#MC_MatcheDetails" title="تفاصيل المباراة">
# <div class="allData">
# <!-- Match Top Data -->
# <!--Time & Status-->
# <div class="topData">
# <div class="date">مبارة ودية</div>
# <div class="matchStatus">
# <span>انتهت</span>
# </div>
# </div>
# <!--Teams-->
# <div class="teamCntnr">
# <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# ...

# %%
matches
# Out:
# [<div class="item finish liItem" livescorematchid="96603">
#  <a href="/friendly-matches-club/2541/match/96603/%d8%a7%d9%84%d8%a3%d9%87%d9%84%d9%8a-%d8%a7%d9%84%d9%86%d8%ac%d9%88%d9%85-%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa-%d9%88%d8%af%d9%8a%d8%a9-%d8%a3%d9%86%d8%af%d9%8a%d8%a9#MC_MatcheDetails" title="تفاصيل المباراة">
#  <div class="allData">
#  <!-- Match Top Data -->
#  <!--Time & Status-->
#  <div class="topData">
#  <div class="date">مبارة ودية</div>
#  <div class="matchStatus">
#  <span>انتهت</span>
#  </div>
#  </div>
#  <!--Teams-->
#  <div class="teamCntnr">
#  <div class="teamsData">
#  <!-- Team A -->
#  <div class="teams teamA">
# ...

# %%
import requests
from bs4 import BeautifulSoup

def get_channel(match_card):
    channel_element = match_card.find('div', {'class': 'channel icon-channel'})
    if channel_element:
        return channel_element.text.strip()
    else:
        return "Empty"
    
Date = input('Please enter the date in the following format MM/DD/YY: ')

# Make an HTTP request
url = f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?{Date}#"
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Find all match cards
champions = soup.find_all('div', {'class': 'matchCard'})

# Initialize an empty list to store all matches
all_matches = []

# Iterate through each champion
for champion in champions:
    # Find all match items within the champion
    matches = champion.find_all('div', {'class': 'item finish liItem'})
    for match in matches:
        # Extract information for each match
        channel = get_channel(champion)
        match_type = match.find('div', {'class': 'date'}).text.strip()
        teamA = match.find('div', {'class': 'teamA'}).text.strip()
        teamB = match.find('div', {'class': 'teamB'}).text.strip()
        scores = match.find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
        score1 = scores[0].text.strip()
        score2 = scores[1].text.strip()
        score = f"{score1}-{score2}"
        time = match.find('div', {'class': 'MResult'}).find('span', {'class': 'time'}).text.strip()

        # Now you can process or print this information as needed
        print(f"Channel: {channel}")
        print(f"Match Type: {match_type}")
        print(f"Team A: {teamA}")
        print(f"Team B: {teamB}")
        print(f"Score: {score}")
        print(f"Time: {time}")
        print("-" * 30)  # Separator between matches

# 'all_matches' now contains all match items for each champion
# Out:
# Please enter the date in the following format MM/DD/YY: 8/6/2024

# %%
import requests
from bs4 import BeautifulSoup

def get_channel(match_card):
    channel_element = match_card.find('div', {'class': 'channel icon-channel'})
    if channel_element:
        return channel_element.text.strip()
    else:
        return "Empty"

# Get the date from the user (format: MM/DD/YYYY)
Date = input('Please enter the date in the following format MM/DD/YYYY: ')

# Construct the URL
url = f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={Date}#"

# Make an HTTP request
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Find all match cards
champions = soup.find_all('div', {'class': 'matchCard'})

# Initialize an empty list to store all matches
all_matches = []

# Iterate through each champion
for champion in champions:
    # Find all match items within the champion
    matches = champion.find_all('div', {'class': 'item finish liItem'})
    for match in matches:
        # Extract information for each match
        channel = get_channel(champion)
        match_type = match.find('div', {'class': 'date'}).text.strip()
        teamA = match.find('div', {'class': 'teamA'}).text.strip()
        teamB = match.find('div', {'class': 'teamB'}).text.strip()
        scores = match.find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
        score1 = scores[0].text.strip()
        score2 = scores[1].text.strip()
        score = f"{score1}-{score2}"
        time = match.find('div', {'class': 'MResult'}).find('span', {'class': 'time'}).text.strip()

        # Now you can process or print this information as needed
        print(f"Channel: {channel}")
        print(f"Match Type: {match_type}")
        print(f"Team A: {teamA}")
        print(f"Team B: {teamB}")
        print(f"Score: {score}")
        print(f"Time: {time}")
        print("-" * 30)  # Separator between matches

# 'all_matches' now contains all match items for each champion
# Out:
# Please enter the date in the following format MM/DD/YYYY: 6/19/2024
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: كرواتيا
# Team B: ألبانيا
# Score: 2-2
# Time: 16:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: ألمانيا
# Team B: المجر
# Score: 2-0
# Time: 19:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: إسكتلندا
# Team B: سويسرا
# Score: 1-1
# Time: 22:00
# ------------------------------
# Channel: Ontime sports 2
# Match Type: الأسبوع السادس والعشرون
# Team A: سيراميكا كليوباترا
# Team B: مودرن فيوتشر
# Score: 0-1
# Time: 19:00
# ------------------------------
# Channel: Ontime sports 2
# Match Type: الأسبوع السادس والعشرون
# Team A: بلدية المحلة
# Team B: بيراميدز
# Score: 0-2
# Time: 19:00
# ------------------------------
# Channel: Empty
# Match Type: الأسبوع العاشر
# Team A: الإتحاد المنستيري
# Team B: الملعب التونسي
# Score: 1-1
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv

def get_channel(match_card):
    channel_element = match_card.find('div', {'class': 'channel icon-channel'})
    if channel_element:
        return channel_element.text.strip()
    else:
        return "Empty"

# Get the date from the user (format: MM/DD/YYYY)
Date = input('Please enter the date in the following format MM/DD/YYYY: ')

# Construct the URL
url = f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={Date}#"

# Make an HTTP request
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Find all match cards
champions = soup.find_all('div', {'class': 'matchCard'})

# Initialize an empty list to store all matches
all_matches = []

# Iterate through each champion
for champion in champions:
    # Find all match items within the champion
    matches = champion.find_all('div', {'class': 'item finish liItem'})
    for match in matches:
        # Extract information for each match
        channel = get_channel(champion)
        match_type = match.find('div', {'class': 'date'}).text.strip()
        teamA = match.find('div', {'class': 'teamA'}).text.strip()
        teamB = match.find('div', {'class': 'teamB'}).text.strip()
        scores = match.find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
        score1 = scores[0].text.strip()
        score2 = scores[1].text.strip()
        score = f"{score1}-{score2}"
        time = match.find('div', {'class': 'MResult'}).find('span', {'class': 'time'}).text.strip()
        all_matches.append({"نوع البطولة ":match_type , "الفريق الاول":teamA , "الفريق الثاني":teamB,"ميعاد المباراة":time,"النتيجة":score})
        # Now you can process or print this information as needed
        print(f"Channel: {channel}")
        print(f"Match Type: {match_type}")
        print(f"Team A: {teamA}")
        print(f"Team B: {teamB}")
        print(f"Score: {score}")
        print(f"Time: {time}")
        print("-" * 30)  # Separator between matches

        # Write match information to CSV
with open('C:\Users\me135\Downloads\Pythonista\Yalla-Cora\Yalla-Cora.csv', 'w', newline='') as csvfile:
    dict_writer = csv.DictWriter(csvfile, all_matches[0].keys)
    # Rest of your code here

    dict_writer.writeheader()
    dict_writer.writerows(all_matches)

        
# 'all_matches' now contains all match items for each champion
# Out:
# Please enter the date in the following format MM/DD/YYYY: 6/19/2024
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: كرواتيا
# Team B: ألبانيا
# Score: 2-2
# Time: 16:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: ألمانيا
# Team B: المجر
# Score: 2-0
# Time: 19:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: إسكتلندا
# Team B: سويسرا
# Score: 1-1
# Time: 22:00
# ------------------------------
# Channel: Ontime sports 2
# Match Type: الأسبوع السادس والعشرون
# Team A: سيراميكا كليوباترا
# Team B: مودرن فيوتشر
# Score: 0-1
# Time: 19:00
# ------------------------------
# Channel: Ontime sports 2
# Match Type: الأسبوع السادس والعشرون
# Team A: بلدية المحلة
# Team B: بيراميدز
# Score: 0-2
# Time: 19:00
# ------------------------------
# Channel: Empty
# Match Type: الأسبوع العاشر
# Team A: الإتحاد المنستيري
# Team B: الملعب التونسي
# Score: 1-1
# ...

# %%
keys = all_matches[1].keys
keys
# Out:
# <function dict.keys>

# %%
import requests
from bs4 import BeautifulSoup
import csv

def get_channel(match_card):
    channel_element = match_card.find('div', {'class': 'channel icon-channel'})
    if channel_element:
        return channel_element.text.strip()
    else:
        return "Empty"

# Get the date from the user (format: MM/DD/YYYY)
Date = input('Please enter the date in the following format MM/DD/YYYY: ')

# Construct the URL
url = f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={Date}#"

# Make an HTTP request
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Find all match cards
champions = soup.find_all('div', {'class': 'matchCard'})

# Initialize an empty list to store all matches
all_matches = []

# Iterate through each champion
for champion in champions:
    # Find all match items within the champion
    matches = champion.find_all('div', {'class': 'item finish liItem'})
    for match in matches:
        # Extract information for each match
        channel = get_channel(champion)
        match_type = match.find('div', {'class': 'date'}).text.strip()
        teamA = match.find('div', {'class': 'teamA'}).text.strip()
        teamB = match.find('div', {'class': 'teamB'}).text.strip()
        scores = match.find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
        score1 = scores[0].text.strip()
        score2 = scores[1].text.strip()
        score = f"{score1}-{score2}"
        time = match.find('div', {'class': 'MResult'}).find('span', {'class': 'time'}).text.strip()
        all_matches.append({"نوع البطولة ":match_type , "الفريق الاول":teamA , "الفريق الثاني":teamB,"ميعاد المباراة":time,"النتيجة":score})
        # Now you can process or print this information as needed
        print(f"Channel: {channel}")
        print(f"Match Type: {match_type}")
        print(f"Team A: {teamA}")
        print(f"Team B: {teamB}")
        print(f"Score: {score}")
        print(f"Time: {time}")
        print("-" * 30)  # Separator between matches

# Define the CSV file name
csv_file = f"matches_{Date.replace('/', '-')}.csv"

# Write the data to a CSV file
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=["نوع البطولة ", "الفريق الاول", "الفريق الثاني", "ميعاد المباراة", "النتيجة"])
    writer.writeheader()
    writer.writerows(all_matches)

print(f"Data has been written to {csv_file}")
# Out:
# Please enter the date in the following format MM/DD/YYYY: 6/19/2024
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: كرواتيا
# Team B: ألبانيا
# Score: 2-2
# Time: 16:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: ألمانيا
# Team B: المجر
# Score: 2-0
# Time: 19:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: إسكتلندا
# Team B: سويسرا
# Score: 1-1
# Time: 22:00
# ------------------------------
# Channel: Ontime sports 2
# Match Type: الأسبوع السادس والعشرون
# Team A: سيراميكا كليوباترا
# Team B: مودرن فيوتشر
# Score: 0-1
# Time: 19:00
# ------------------------------
# Channel: Ontime sports 2
# Match Type: الأسبوع السادس والعشرون
# Team A: بلدية المحلة
# Team B: بيراميدز
# Score: 0-2
# Time: 19:00
# ------------------------------
# Channel: Empty
# Match Type: الأسبوع العاشر
# Team A: الإتحاد المنستيري
# Team B: الملعب التونسي
# Score: 1-1
# ...

# %%
import os

# Define the CSV file name
csv_file = f"matches_{Date.replace('/', '-')}.csv"

# Get the absolute path of the CSV file
abs_path = os.path.abspath(csv_file)

# Write the data to a CSV file
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=["نوع البطولة ", "الفريق الاول", "الفريق الثاني", "ميعاد المباراة", "النتيجة"])
    writer.writeheader()
    writer.writerows(all_matches)

print(f"Data has been written to {abs_path}")
# Out:
# Data has been written to C:\Users\me135\matches_6-19-2024.csv

# %%
import requests
from bs4 import BeautifulSoup
import csv

def get_channel(match_card):
    channel_element = match_card.find('div', {'class': 'channel icon-channel'})
    if channel_element:
        return channel_element.text.strip()
    else:
        return "Empty"

# Get the date from the user (format: MM/DD/YYYY)
Date = input('Please enter the date in the following format MM/DD/YYYY: ')

# Construct the URL
url = f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={Date}#"

# Make an HTTP request
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Find all match cards
champions = soup.find_all('div', {'class': 'matchCard'})

# Initialize an empty list to store all matches
all_matches = []

# Iterate through each champion
for champion in champions:
    # Find all match items within the champion
    matches = champion.find_all('div', {'class': 'item finish liItem'})
    for match in matches:
        # Extract information for each match
        channel = get_channel(champion)
        match_type = match.find('div', {'class': 'date'}).text.strip()
        teamA = match.find('div', {'class': 'teamA'}).text.strip()
        teamB = match.find('div', {'class': 'teamB'}).text.strip()
        scores = match.find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
        score1 = scores[0].text.strip()
        score2 = scores[1].text.strip()
        score = f"{score1}-{score2}"
        time = match.find('div', {'class': 'MResult'}).find('span', {'class': 'time'}).text.strip()
        all_matches.append({"نوع البطولة ": match_type, "الفريق الاول": teamA, "الفريق الثاني": teamB, "ميعاد المباراة": time, "النتيجة": score})
        # Now you can process or print this information as needed
        print(f"Channel: {channel}")
        print(f"Match Type: {match_type}")
        print(f"Team A: {teamA}")
        print(f"Team B: {teamB}")
        print(f"Score: {score}")
        print(f"Time: {time}")
        print("-" * 30)  # Separator between matches



# Write the data to a CSV file with UTF-8 encoding
with open(csv_file, mode='w', newline='', encoding='utf-8-sig') as file:
    writer = csv.DictWriter(file, fieldnames=["نوع البطولة ", "الفريق الاول", "الفريق الثاني", "ميعاد المباراة", "النتيجة"])
    writer.writeheader()
    writer.writerows(all_matches)
# Out:
# Please enter the date in the following format MM/DD/YYYY: 6/19/2024
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: كرواتيا
# Team B: ألبانيا
# Score: 2-2
# Time: 16:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: ألمانيا
# Team B: المجر
# Score: 2-0
# Time: 19:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: الجولة الثانية
# Team A: إسكتلندا
# Team B: سويسرا
# Score: 1-1
# Time: 22:00
# ------------------------------
# Channel: Ontime sports 2
# Match Type: الأسبوع السادس والعشرون
# Team A: سيراميكا كليوباترا
# Team B: مودرن فيوتشر
# Score: 0-1
# Time: 19:00
# ------------------------------
# Channel: Ontime sports 2
# Match Type: الأسبوع السادس والعشرون
# Team A: بلدية المحلة
# Team B: بيراميدز
# Score: 0-2
# Time: 19:00
# ------------------------------
# Channel: Empty
# Match Type: الأسبوع العاشر
# Team A: الإتحاد المنستيري
# Team B: الملعب التونسي
# Score: 1-1
# ...

# %%
import os
import requests
from bs4 import BeautifulSoup
import csv

def get_channel(match_card):
    channel_element = match_card.find('div', {'class': 'channel icon-channel'})
    if channel_element:
        return channel_element.text.strip()
    else:
        return "Empty"

# Get the date from the user (format: MM/DD/YYYY)
Date = input('Please enter the date in the following format MM/DD/YYYY: ')

# Construct the URL
url = f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={Date}#"

# Make an HTTP request
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Find all match cards
champions = soup.find_all('div', {'class': 'matchCard'})

# Initialize an empty list to store all matches
all_matches = []

# Iterate through each champion
for champion in champions:
    # Find all match items within the champion
    matches = champion.find_all('div', {'class': 'item finish liItem'})
    match_type = champion.find('div', {'class': 'title'}).find('h2').text.strip()
    for match in matches:
        # Extract information for each match
        channel = get_channel(champion)
        
        teamA = match.find('div', {'class': 'teamA'}).text.strip()
        teamB = match.find('div', {'class': 'teamB'}).text.strip()
        
        score_element = match.find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
        if len(score_element) == 2:
            score1 = score_element[0].text.strip()
            score2 = score_element[1].text.strip()
            score = f"{score1}-{score2}"
        else:
            score = "N/A"  # Handle cases where the score is not available or improperly formatted
        
        time = match.find('div', {'class': 'MResult'}).find('span', {'class': 'time'}).text.strip()
        
        all_matches.append({"نوع البطولة ": match_type, "الفريق الاول": teamA, "الفريق الثاني": teamB, "ميعاد المباراة": time, "النتيجة": score})
        # Now you can process or print this information as needed
        print(f"Channel: {channel}")
        print(f"Match Type: {match_type}")
        print(f"Team A: {teamA}")
        print(f"Team B: {teamB}")
        print(f"Score: {score}")
        print(f"Time: {time}")
        print("-" * 30)  # Separator between matches

# Define the CSV file name and path
home_directory = os.path.expanduser("~")
csv_file = os.path.join(home_directory, f"matches_{Date.replace('/', '-')}.csv")

# Write the data to a CSV file with UTF-8 encoding
with open(csv_file, mode='w', newline='', encoding='utf-8-sig') as file:
    writer = csv.DictWriter(file, fieldnames=["نوع البطولة ", "الفريق الاول", "الفريق الثاني", "ميعاد المباراة", "النتيجة"])
    writer.writeheader()
    writer.writerows(all_matches)

print(f"Data has been written to {csv_file}")
# Out:
# Please enter the date in the following format MM/DD/YYYY: 6/20/2024
# Channel: beIN SPORTS MAX HD1
# Match Type: يورو 2024
# Team A: سلوفينيا
# Team B: صربيا
# Score: 1-1
# Time: 16:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: يورو 2024
# Team A: الدنمارك
# Team B: إنجلترا
# Score: 1-1
# Time: 19:00
# ------------------------------
# Channel: beIN SPORTS MAX HD1
# Match Type: يورو 2024
# Team A: إسبانيا
# Team B: إيطاليا
# Score: 1-0
# Time: 22:00
# ------------------------------
# Channel: Ontime sports 1
# Match Type: الدورة المؤهلة للدوري الممتاز
# Team A: حرس الحدود
# Team B: الترسانة
# Score: 2-1
# Time: 17:30
# ------------------------------
# Channel: Ontime sports 1
# Match Type: الدورة المؤهلة للدوري الممتاز
# Team A: منتخب السويس
# Team B: سبورتنج
# Score: 2-2
# Time: 17:30
# ------------------------------
# Channel: Empty
# Match Type: الدوري التونسي
# Team A: الصفاقســــي
# Team B: الترجى الرياضي
# Score: 0-0
# Time: 19:30
# ...

# %%
import os
import requests
from bs4 import BeautifulSoup
import csv

def get_channel(match_card):
    channel_element = match_card.find('div', {'class': 'channel icon-channel'})
    if channel_element:
        return channel_element.text.strip()
    else:
        return "Empty"

# Get the date from the user (format: MM/DD/YYYY)
Date = input('Please enter the date in the following format MM/DD/YYYY: ')

# Construct the URL
url = f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={Date}#"

# Make an HTTP request
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Find all match cards
champions = soup.find_all('div', {'class': 'matchCard'})

# Initialize an empty list to store all matches
all_matches = []

# Iterate through each champion
for champion in champions:
    # Find all match items within the champion
    matches = champion.find_all('div', {'class': 'item finish liItem'})
    for match in matches:
        # Extract information for each match
        channel = get_channel(champion)
        match_type = match.find('div', {'class': 'date'}).text.strip()
        teamA = match.find('div', {'class': 'teamA'}).text.strip()
        teamB = match.find('div', {'class': 'teamB'}).text.strip()
        
        score_element = match.find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
        if len(score_element) == 2:
            score1 = score_element[0].text.strip()
            score2 = score_element[1].text.strip()
            score = f"{score1}-{score2}"
        else:
            score = "N/A"  # Handle cases where the score is not available or improperly formatted
        
        time = match.find('div', {'class': 'MResult'}).find('span', {'class': 'time'}).text.strip()
        
        all_matches.append({"نوع البطولة ": match_type, "الفريق الاول": teamA, "الفريق الثاني": teamB, "ميعاد المباراة": time, "النتيجة": score, "القناة": channel})
        # Now you can process or print this information as needed
        print(f"Channel: {channel}")
        print(f"Match Type: {match_type}")
        print(f"Team A: {teamA}")
        print(f"Team B: {teamB}")
        print(f"Score: {score}")
        print(f"Time: {time}")
        print("-" * 30)  # Separator between matches

# Define the CSV file name and path
home_directory = os.path.expanduser("~")
csv_file = os.path.join(home_directory, f"matches_{Date.replace('/', '-')}.csv")

# Write the data to a CSV file with UTF-8 encoding
with open('C:/Users/me135/scraping.csv')as csv_file:
    dict_writer = csv.dict_writer(csv_file,all_matches[0])

    dict_writer.writeheader()
    dict_writer.writerows(all_matches)

print(f"Data has been written to {csv_file}")
# Out:
# Please enter the date in the following format MM/DD/YYYY: 4/1/2025
# Channel: بى ان سبورت 6 HD
# Match Type: ذهاب دور ال8
# Team A: ماميلودي صنداونز
# Team B: الترجى الرياضي
# Score: 1-0
# Time: 15:00
# ------------------------------
# Channel: بى ان سبورت 6 HD
# Match Type: ذهاب دور ال8
# Team A: مولودية الجزائر
# Team B: أورلاندو بايرتس
# Score: 0-1
# Time: 21:00
# ------------------------------
# Channel: بى ان سبورت 6 HD
# Match Type: ذهاب دور ال8
# Team A: الأهلي
# Team B: الهلال السوداني
# Score: 1-0
# Time: 21:00
# ------------------------------
# Channel: بى ان سبورت 6 HD
# Match Type: ذهاب دور ال8
# Team A: بيراميدز
# Team B: الجيش الملكي
# Score: 4-1
# Time: 21:00
# ------------------------------
# Channel: بى ان سبورت 2 HD
# Match Type: الأسبوع الثلاثون
# Team A: أرسنال
# Team B: فولهام
# Score: 2-1
# Time: 20:45
# ------------------------------
# Channel: بى ان سبورت 2 HD
# Match Type: الأسبوع الثلاثون
# Team A: وولفرهامبتون
# Team B: وست هام يونايتد
# Score: 1-0
# ...

# %%
with open(csv_file, mode='w', newline='', encoding='utf-8-sig') as file:
    writer = csv.DictWriter(file, fieldnames=["نوع البطولة ", "الفريق الاول", "الفريق الثاني", "ميعاد المباراة", "النتيجة", "القناة"])
    # Define the CSV file name
